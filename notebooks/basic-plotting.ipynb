# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("result_df.csv")
chi_omega_df = df[["m_chi_10", "MO_Omega"]]
chi_omega_df.head()
# Out:
#     m_chi_10  MO_Omega
# 0  160.95575  0.000961
# 1  153.45103  0.000900
# 2   78.72527  0.000391
# 3  126.63868  0.001080
# 4  274.36227  0.002040

# %%
m_chi_10 = chi_omega_df.m_chi_10.values
MO_Omega = chi_omega_df.MO_Omega.values
plt.scatter(m_chi_10, MO_Omega, s=1)
plt.yscale("log")
plt.xscale("log")
plt.xlim([10, 10**3])
plt.ylim([10**-3.8, 10**1.3])
plt.axhline(0.12)

# %% [markdown]
# I'm trying to recreate figure 2 from the pMSSM paper on page 9. The three distinct lines pointing up and right do exist in the original plot, but a number of things don't line up. The line at 0.12 should pass through the top of the top distinct line, and there should be a kind of smile shape in the top right of the plot.
